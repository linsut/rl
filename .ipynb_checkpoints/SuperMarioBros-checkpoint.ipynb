# %% [markdown]
# # Super Mario Bros Reinforcement Learning Algorithms
#
# ## Part 1: Setup Mario

# %%
# Import the game
import gym_super_mario_bros
# Import the controls
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# Simplifies the controls, takes out all actions that don't make sense
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
# Random agent
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the game
        env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())
    # Show the game on the screen
    env.render()
# Close the game
env.close()

# %%
env.close()

# %% [markdown]
# ## Preprocessing

# %%
# Wrappers to simplify environment: grayscale
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# ## Train model

# %%
# Import os for file path management
import os 
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = 'D:/Lina/rl_models/mario_ppo/train/'
LOG_DIR = 'D:/Lina/rl_models/mario_ppo/logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=100000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ### PPO

# %%
# Import PPO for algos
from stable_baselines3 import PPO

# This is the AI model
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# ### A2C

# %%
# Import PPO for algos
from stable_baselines3 import PPO

model = A2C('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)

# %% [markdown]
# ## Learning

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=4000000, callback=callback)
# Out:
# Logging to D:/Lina/rl_models/mario_ppo/logs/PPO_2
# ----------------------------
# | time/              |     |
# |    fps             | 184 |
# |    iterations      | 1   |
# |    time_elapsed    | 2   |
# |    total_timesteps | 512 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.001397033 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 70.1        |
# |    n_updates            | 70320       |
# |    policy_gradient_loss | -0.000138   |
# |    value_loss           | 141         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 89            |
# |    iterations           | 3             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 0.00011209445 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.14         |
# |    explained_variance   | 0.68          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 227           |
# |    n_updates            | 70330         |
# |    policy_gradient_loss | -0.000122     |
# |    value_loss           | 658           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 4            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0008048024 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.19        |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 52.4         |
# |    n_updates            | 70340        |
# |    policy_gradient_loss | -0.000804    |
# |    value_loss           | 146          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 80            |
# |    iterations           | 5             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 0.00037249038 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.113        |
# |    explained_variance   | 0.82          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 336           |
# |    n_updates            | 70350         |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 613           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 6            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0001335364 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 138          |
# |    n_updates            | 70360        |
# |    policy_gradient_loss | 0.00101      |
# |    value_loss           | 545          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 7            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0009601398 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.184       |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 182          |
# |    n_updates            | 70370        |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 494          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 8            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0009204929 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.201       |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 99.4         |
# |    n_updates            | 70380        |
# |    policy_gradient_loss | -0.000862    |
# |    value_loss           | 230          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 74            |
# |    iterations           | 9             |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 0.00027061568 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.146        |
# |    explained_variance   | 0.81          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 37.1          |
# |    n_updates            | 70390         |
# |    policy_gradient_loss | -0.000416     |
# |    value_loss           | 155           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 10          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011411358 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.335      |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 297         |
# |    n_updates            | 70400       |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 585         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 11           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0046901745 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.292       |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 53.4         |
# |    n_updates            | 70410        |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 12           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0010119787 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.328       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 172          |
# |    n_updates            | 70420        |
# |    policy_gradient_loss | 0.000167     |
# |    value_loss           | 297          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 13           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 0.0010157567 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 122          |
# |    n_updates            | 70430        |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 237          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 14          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.007262543 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 79          |
# |    n_updates            | 70440       |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 219         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 71            |
# |    iterations           | 15            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 4.8005255e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.161        |
# |    explained_variance   | 0.856         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 90.7          |
# |    n_updates            | 70450         |
# |    policy_gradient_loss | -5.96e-05     |
# |    value_loss           | 199           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 16           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0013169419 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 205          |
# |    n_updates            | 70460        |
# |    policy_gradient_loss | -0.000202    |
# |    value_loss           | 790          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 17           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0004117426 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.13        |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 578          |
# |    n_updates            | 70470        |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 796          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 18            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00013496995 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.162        |
# |    explained_variance   | 0.709         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 194           |
# |    n_updates            | 70480         |
# |    policy_gradient_loss | 0.000631      |
# |    value_loss           | 659           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 19          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.000879716 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 124         |
# |    n_updates            | 70490       |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 247         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 20            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00020410947 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.245        |
# |    explained_variance   | 0.908         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 118           |
# |    n_updates            | 70500         |
# |    policy_gradient_loss | 0.000569      |
# |    value_loss           | 233           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 21           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0013797733 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.191       |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 122          |
# |    n_updates            | 70510        |
# |    policy_gradient_loss | 0.00041      |
# |    value_loss           | 271          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 22           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0017411049 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.172       |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 75.4         |
# |    n_updates            | 70520        |
# |    policy_gradient_loss | 0.00161      |
# |    value_loss           | 179          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 23           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0011484828 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 196          |
# |    n_updates            | 70530        |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 664          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 24            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00034006836 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.168        |
# |    explained_variance   | 0.822         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 169           |
# |    n_updates            | 70540         |
# |    policy_gradient_loss | -0.000578     |
# |    value_loss           | 299           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 25           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0010356557 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 57.7         |
# |    n_updates            | 70550        |
# |    policy_gradient_loss | -0.000549    |
# |    value_loss           | 140          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 26           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0006599986 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 69.8         |
# |    n_updates            | 70560        |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 185          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 27            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 0.00070613367 |
# |    clip_fraction        | 0.00273       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.174        |
# |    explained_variance   | 0.601         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 305           |
# |    n_updates            | 70570         |
# |    policy_gradient_loss | -0.00198      |
# |    value_loss           | 811           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 28           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0009136675 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.184       |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 54           |
# |    n_updates            | 70580        |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 210          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 29          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.001378447 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 176         |
# |    n_updates            | 70590       |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 270         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 30           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 9.689294e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.187       |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 644          |
# |    n_updates            | 70600        |
# |    policy_gradient_loss | -0.000365    |
# |    value_loss           | 834          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 31           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 0.0007454456 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 154          |
# |    n_updates            | 70610        |
# |    policy_gradient_loss | -0.000975    |
# |    value_loss           | 316          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 32           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0049310555 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 44.3         |
# |    n_updates            | 70620        |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 33           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0002298021 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.187       |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 245          |
# |    n_updates            | 70630        |
# |    policy_gradient_loss | -0.000536    |
# |    value_loss           | 680          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 34           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0026012277 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 49.2         |
# |    n_updates            | 70640        |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 161          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 35          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.001380719 |
# |    clip_fraction        | 0.000586    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.377      |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 206         |
# |    n_updates            | 70650       |
# |    policy_gradient_loss | 1.56e-06    |
# |    value_loss           | 347         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 36            |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00038292666 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.356        |
# |    explained_variance   | 0.568         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 364           |
# |    n_updates            | 70660         |
# |    policy_gradient_loss | 0.000243      |
# |    value_loss           | 834           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 37           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 0.0010058959 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 92.1         |
# |    n_updates            | 70670        |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 181          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 38          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.008538624 |
# |    clip_fraction        | 0.00801     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.591      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 3.71        |
# |    n_updates            | 70680       |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 10.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 39           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 0.0005145981 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -1.14        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.86         |
# |    n_updates            | 70690        |
# |    policy_gradient_loss | -0.000425    |
# |    value_loss           | 9.07         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 40           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0011142457 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 83.8         |
# |    n_updates            | 70700        |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 41           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 20992        |
# | train/                  |              |
# |    approx_kl            | 0.0010805697 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.553        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 192          |
# |    n_updates            | 70710        |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 428          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 42            |
# |    time_elapsed         | 309           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 0.00011751335 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.172        |
# |    explained_variance   | 0.675         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 730           |
# |    n_updates            | 70720         |
# |    policy_gradient_loss | -0.000787     |
# |    value_loss           | 604           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 43            |
# |    time_elapsed         | 316           |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 0.00025497098 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0945       |
# |    explained_variance   | 0.891         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 64.9          |
# |    n_updates            | 70730         |
# |    policy_gradient_loss | -0.000714     |
# |    value_loss           | 182           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 44            |
# |    time_elapsed         | 323           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 3.4637167e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0887       |
# |    explained_variance   | 0.7           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 217           |
# |    n_updates            | 70740         |
# |    policy_gradient_loss | -3.27e-06     |
# |    value_loss           | 645           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 45            |
# |    time_elapsed         | 331           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 0.00018994545 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.104        |
# |    explained_variance   | 0.52          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 295           |
# |    n_updates            | 70750         |
# |    policy_gradient_loss | -0.00053      |
# |    value_loss           | 715           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 46            |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 2.6751659e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.116        |
# |    explained_variance   | 0.575         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 239           |
# |    n_updates            | 70760         |
# |    policy_gradient_loss | 0.000422      |
# |    value_loss           | 789           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 47            |
# |    time_elapsed         | 346           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 0.00010469963 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.225        |
# |    explained_variance   | 0.957         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 53.3          |
# |    n_updates            | 70770         |
# |    policy_gradient_loss | -0.000199     |
# |    value_loss           | 151           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 48            |
# |    time_elapsed         | 353           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 8.6153625e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.129        |
# |    explained_variance   | 0.602         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 285           |
# |    n_updates            | 70780         |
# |    policy_gradient_loss | -0.000401     |
# |    value_loss           | 541           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 49           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 6.908784e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.123       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 23.6         |
# |    n_updates            | 70790        |
# |    policy_gradient_loss | -0.00065     |
# |    value_loss           | 75.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 50           |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 5.339773e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.141       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 177          |
# |    n_updates            | 70800        |
# |    policy_gradient_loss | -0.000169    |
# |    value_loss           | 459          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 51           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0017357958 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 188          |
# |    n_updates            | 70810        |
# |    policy_gradient_loss | -0.000779    |
# |    value_loss           | 523          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 52           |
# |    time_elapsed         | 382          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0067095077 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.362       |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 38.4         |
# |    n_updates            | 70820        |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 155          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 53            |
# |    time_elapsed         | 390           |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 0.00024269347 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.283        |
# |    explained_variance   | 0.715         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 411           |
# |    n_updates            | 70830         |
# |    policy_gradient_loss | -0.00013      |
# |    value_loss           | 781           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 54            |
# |    time_elapsed         | 397           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 0.00059784413 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.216        |
# |    explained_variance   | 0.66          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 162           |
# |    n_updates            | 70840         |
# |    policy_gradient_loss | -0.00087      |
# |    value_loss           | 601           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 55            |
# |    time_elapsed         | 405           |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 0.00033511536 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.234        |
# |    explained_variance   | 0.898         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 70.3          |
# |    n_updates            | 70850         |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 146           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 56            |
# |    time_elapsed         | 412           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00015602773 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.219        |
# |    explained_variance   | 0.767         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 235           |
# |    n_updates            | 70860         |
# |    policy_gradient_loss | -0.000521     |
# |    value_loss           | 715           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 57           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 29184        |
# | train/                  |              |
# |    approx_kl            | 0.0005322865 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 78           |
# |    n_updates            | 70870        |
# |    policy_gradient_loss | -0.000658    |
# |    value_loss           | 193          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 58            |
# |    time_elapsed         | 427           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00088520045 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.251        |
# |    explained_variance   | 0.93          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 76.5          |
# |    n_updates            | 70880         |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 193           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 59           |
# |    time_elapsed         | 434          |
# |    total_timesteps      | 30208        |
# | train/                  |              |
# |    approx_kl            | 0.0010397393 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 109          |
# |    n_updates            | 70890        |
# |    policy_gradient_loss | 0.000411     |
# |    value_loss           | 228          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 60            |
# |    time_elapsed         | 442           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00020098186 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.134        |
# |    explained_variance   | 0.824         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 69.3          |
# |    n_updates            | 70900         |
# |    policy_gradient_loss | -0.000121     |
# |    value_loss           | 263           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 61           |
# |    time_elapsed         | 450          |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 7.921469e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.16        |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 374          |
# |    n_updates            | 70910        |
# |    policy_gradient_loss | 0.00037      |
# |    value_loss           | 531          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 62            |
# |    time_elapsed         | 457           |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 0.00022234337 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.168        |
# |    explained_variance   | 0.805         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 223           |
# |    n_updates            | 70920         |
# |    policy_gradient_loss | -0.000938     |
# |    value_loss           | 468           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 69            |
# |    iterations           | 63            |
# |    time_elapsed         | 465           |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0028815805 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 119          |
# |    n_updates            | 77920        |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 573          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 763          |
# |    time_elapsed         | 5515         |
# |    total_timesteps      | 390656       |
# | train/                  |              |
# |    approx_kl            | 0.0028558918 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 34.4         |
# |    n_updates            | 77930        |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 121          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 764         |
# |    time_elapsed         | 5523        |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.001026481 |
# |    clip_fraction        | 0.000781    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 102         |
# |    n_updates            | 77940       |
# |    policy_gradient_loss | -0.000273   |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 765         |
# |    time_elapsed         | 5530        |
# |    total_timesteps      | 391680      |
# | train/                  |             |
# |    approx_kl            | 0.000845226 |
# |    clip_fraction        | 0.000195    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 157         |
# |    n_updates            | 77950       |
# |    policy_gradient_loss | -0.000986   |
# |    value_loss           | 399         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 766          |
# |    time_elapsed         | 5537         |
# |    total_timesteps      | 392192       |
# | train/                  |              |
# |    approx_kl            | 0.0026822304 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 79.5         |
# |    n_updates            | 77960        |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 224          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 767          |
# |    time_elapsed         | 5544         |
# |    total_timesteps      | 392704       |
# | train/                  |              |
# |    approx_kl            | 0.0015274605 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.385       |
# |    explained_variance   | 0.667        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 126          |
# |    n_updates            | 77970        |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 281          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 768          |
# |    time_elapsed         | 5551         |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0031498247 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 176          |
# |    n_updates            | 77980        |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 459          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 769           |
# |    time_elapsed         | 5558          |
# |    total_timesteps      | 393728        |
# | train/                  |               |
# |    approx_kl            | 0.00094200566 |
# |    clip_fraction        | 0.00254       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.416        |
# |    explained_variance   | 0.891         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 112           |
# |    n_updates            | 77990         |
# |    policy_gradient_loss | -0.000704     |
# |    value_loss           | 222           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 770         |
# |    time_elapsed         | 5565        |
# |    total_timesteps      | 394240      |
# | train/                  |             |
# |    approx_kl            | 0.002114411 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 205         |
# |    n_updates            | 78000       |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 429         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 771           |
# |    time_elapsed         | 5572          |
# |    total_timesteps      | 394752        |
# | train/                  |               |
# |    approx_kl            | 0.00043869612 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.4          |
# |    explained_variance   | 0.488         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 467           |
# |    n_updates            | 78010         |
# |    policy_gradient_loss | 0.000545      |
# |    value_loss           | 863           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 772          |
# |    time_elapsed         | 5579         |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0029001809 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 87.2         |
# |    n_updates            | 78020        |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 231          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 773           |
# |    time_elapsed         | 5586          |
# |    total_timesteps      | 395776        |
# | train/                  |               |
# |    approx_kl            | 0.00096771354 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.378        |
# |    explained_variance   | 0.82          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 451           |
# |    n_updates            | 78030         |
# |    policy_gradient_loss | -3.24e-05     |
# |    value_loss           | 531           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 774          |
# |    time_elapsed         | 5593         |
# |    total_timesteps      | 396288       |
# | train/                  |              |
# |    approx_kl            | 0.0027676113 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 181          |
# |    n_updates            | 78040        |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 436          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 775          |
# |    time_elapsed         | 5600         |
# |    total_timesteps      | 396800       |
# | train/                  |              |
# |    approx_kl            | 0.0020057554 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 61.2         |
# |    n_updates            | 78050        |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 153          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 776          |
# |    time_elapsed         | 5607         |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.0035577524 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.393       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 444          |
# |    n_updates            | 78060        |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 751          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 70            |
# |    iterations           | 777           |
# |    time_elapsed         | 5615          |
# |    total_timesteps      | 397824        |
# | train/                  |               |
# |    approx_kl            | 0.00073605287 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.371        |
# |    explained_variance   | 0.695         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 86.6          |
# |    n_updates            | 78070         |
# |    policy_gradient_loss | -0.000214     |
# |    value_loss           | 210           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 778          |
# |    time_elapsed         | 5622         |
# |    total_timesteps      | 398336       |
# | train/                  |              |
# |    approx_kl            | 0.0003324058 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 94.6         |
# |    n_updates            | 78080        |
# |    policy_gradient_loss | 0.000531     |
# |    value_loss           | 238          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 779          |
# |    time_elapsed         | 5629         |
# |    total_timesteps      | 398848       |
# | train/                  |              |
# |    approx_kl            | 0.0043505277 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 45.7         |
# |    n_updates            | 78090        |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 316          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 780          |
# |    time_elapsed         | 5638         |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0014943228 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 62.4         |
# |    n_updates            | 78100        |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 139          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 781          |
# |    time_elapsed         | 5645         |
# |    total_timesteps      | 399872       |
# | train/                  |              |
# |    approx_kl            | 0.0006738043 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 132          |
# |    n_updates            | 78110        |
# |    policy_gradient_loss | 0.000237     |
# |    value_loss           | 374          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 782         |
# |    time_elapsed         | 5652        |
# |    total_timesteps      | 400384      |
# | train/                  |             |
# |    approx_kl            | 0.002158946 |
# |    clip_fraction        | 0.00449     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 134         |
# |    n_updates            | 78120       |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 324         |
# -----------------------------------------

# %% [markdown]
# ## Testing

# %%
# Load model
model = PPO.load(CHECKPOINT_DIR + 'best_model_3000000')

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()

# %%
env.close()
